# %%
barang = []

while True:
  print('''1. Menambah
2. Menghapus
3. Mengedit
4. Menampilkan
5. Memeriksa Barang
6. Mencari Index''')
  perintah = input("Masukkan perintah: ")
    
  if perintah == '1':
    tmb = input("Masukkan Barang: ")
    barang.append(tmb)
  elif perintah == '2':
    hps = input("Masukkan Barang yang akan dihapus:")
    barang.remove(hps)
  elif perintah == '3':
    edit = input("Masukkan Barang yang akan diedit:")
    index = None
    for i in range(len(barang)):
      if barang [i] == edit:
        index = i
        
    if index == None:
      print("Barang tidak ditemukan.")
    else:
      barang [index] = input("Masukkan Barang yang baru:")
  elif perintah == '4':
    print(barang)
  elif perintah == '5':
    cari = input("Masukkan barang yang dicari:")
    book = False
    
    for i in range(len(barang)):
      if barang [i] == cari:
          print("Barang ditemukan")
          book = True
            
    if book == False:
      print("Barang tidak ditemukan")
  elif perintah == '6':
    cariz = input("Masukkan Barang yang akan dicari indexnya:")
    index = None
    for i in range(len(barang)):
      if barang [i] == cariz:
        index =1
            
    if index == None:
      print("Barang tidak ditemukan.")
    else:
        print("{} ada pada index ke-{}". format(cariz, index))
  else:
    break
    
print("Program Berhenti. Sampai Jumpa")
# Out:
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: 1
# Masukkan Barang: Tas
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: 1
# Masukkan Barang: Buku
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: 1
# Masukkan Barang: Pensil
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: 1
# Masukkan Barang: Dompet
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: 4
# ['Tas', 'Buku', 'Pensil', 'Dompet']
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: 2
# Masukkan Barang yang akan dihapus:Dompet
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: 4
# ['Tas', 'Buku', 'Pensil']
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: 3
# Masukkan Barang yang akan diedit:Pensil
# Masukkan Barang yang baru:Pulpen
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: 4
# ['Tas', 'Buku', 'Pulpen']
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: 5
# Masukkan barang yang dicari:Pulpen
# Barang ditemukan
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: 6
# Masukkan Barang yang akan dicari indexnya:Buku
# Buku ada pada index ke-1
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan perintah: n
# Program Berhenti. Sampai Jumpa
